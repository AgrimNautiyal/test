# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('tosqlnew2.csv', encoding = 'iso-8859-1')

# %%
df.to_csv('tosqlnew2_utf.csv', encoding = 'utf')

# %%
df2 = pd.read_csv('tosqlnew2_utf.csv')

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'linkedinProfile', 'imgUrl', 'firstName', 'lastName',
#        'fullName', 'connectionDegree', 'vmid', 'linkedinSalesNavigatorUrl',
#        'mutualConnectionsUrl', 'company', 'jobTitle', 'jobDescription',
#        'company2', 'jobTitle2', 'jobDescription2', 'school', 'schoolDegree',
#        'schoolDescription', 'schoolDegreeSpec', 'school2', 'schoolDegree2',
#        'schoolDescription2', 'schoolDegreeSpec2', 'allSkills', 'skill1',
#        'endorsement1', 'skill2', 'endorsement2', 'skill3', 'endorsement3',
#        'skill4', 'endorsement4', 'skill5', 'endorsement5', 'skill6',
#        'endorsement6', 'baseUrl', 'profileId', 'mail', 'phoneNumber',
#        'connectionsUrl', 'facebookUrl', 'twitter', 'CompanyID_fromCompanyUrl',
#        'Location_city1', 'Location_country1', 'StartMonth_of_Job1',
#        'StartYear_of_Job1', 'EndMonth_of_Job1', 'EndYear_of_Job1',
#        'CompanyID2_fromCompanyUrl2', 'Location_city2', 'Location_country2',
# ...

# %%
#now let us extract all company names :
company_id = list(set(list(df2['CompanyID_fromCompanyUrl'])))
company_names = list(set(list(df2['company'])))

# %%
df_company = df2[['company', 'CompanyID_fromCompanyUrl']]

# %%
company_names
# Out:
# ['calyxpod                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
# ...
